# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from torch.utils.data import Subset
import numpy as np

import pandas as pd
import os
from PIL import Image
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import random

# %%
kaggle_env = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', 'Localhost') == 'Interactive'
kaggle_env
# Out:
# True

# %%
if not kaggle_env:
    dottless_text_file = 'dotless_text.txt'
    original_text_file = 'original_text.txt'
else: 
    dottless_text_file = '/kaggle/input/arabic-dottization-dataset/dotless_text.txt'
    original_text_file = '/kaggle/input/arabic-dottization-dataset/original_text.txt'

# load the data
with open(dottless_text_file, 'r', encoding='utf-8') as f:
    dottless_text_list = f.readlines()

with open(original_text_file, 'r', encoding='utf-8') as f:
    original_text_list = f.readlines()


print(dottless_text_list[3])
print(original_text_list[3])
# Out:
#  ٮوحد ٮوعاں مں محطاٮ الٮلڡار: المحطاٮ الٮحارٮه والمحطاٮ العامه. ٮدار المحطاٮ الٮحارٮه ٮواسطه سركاٮ حاصه. وٮٮٮع هده السركاٮ وڡٮ الإعلاٮاٮ لٮعطٮه ٮڡڡاٮ الٮسعٮل، ٮالإصاڡه لٮحڡٮٯ رٮح للسركاٮ الٮى ٮدٮر المحطاٮ. أما محطاٮ الٮلڡار العامه ڡهى محطاٮ لا ٮهدڡ إلى الرٮح وٮدار وڡٯ ٮرٮٮٮاٮ حاصه. ڡمٮلا ٮحصل هٮئه الإداعه الٮرٮطاٮٮه على الٮموٮل مں رسوم الٮرحٮص الٮى ٮدڡعها مالكو أحهره الٮلڡار وهى لا ٮٮٮع وڡٮا للإعلاٮاٮ. وٮعٮمد محطاٮ الٮلڡار العامه ڡى معطم الدول، على مساهماٮ ڡطاع الأعمال، والحكومه، والحمهور، ودلك لٮعطٮه ٮڡڡاٮ الٮسعٮل، ومں ٮم ڡإٮهم ٮٮحدوں ڡراراٮهم ٮسأں محٮوٮاٮ الٮرامح ٮأٮڡسهم. وڡى دول أحرى ٮڡوم الحكوماٮ ٮإداره محطاٮ الٮلڡار الٮى ٮٮحد الڡراراٮ ٮسأں محٮوٮاٮ الٮرامح. وٮصڡه عامه لا ٮٮٮع هده المحطاٮ وڡٮا للإعلاں. ٮسٮطٮع الأڡراد ڡى ٮعص الدول الاسٮراك ڡى أٮطمه الٮلڡار الكٮلى (حط الماٮكرووٮڡ) وأٮطمه الٮٮ لمساهدوں رسوما لهده الحدماٮ. كما ٮوحد اسٮحداماٮ أحرى للٮلڡار عٮر ٮٮ الٮرامح للمٮارل. ڡمٮلا، ٮسٮحدم المدارس، وڡطاع الأعمال، والمسٮسڡٮاٮ، وعٮرها مں المٮطماٮ دوائر الٮلڡار المعلڡه. وٮرسل الإساراٮ ڡى مٮل هده الدوائر عٮر أسلاك إلى أحهره ٮلڡار ٮعٮٮها، ولا ٮسٮطٮع ٮڡٮه الأحهره الموحوده ڡى المٮطڡه الٮڡاط ٮلك الإساراٮ ٮالطرٮڡه العادٮه. وڡد عٮرٮ الأحهره الحدٮٮه كمسحلاٮ الڡٮدٮو كاسٮٮ، ومسعلاٮ أڡراص الڡٮدٮو، والحاسوٮ السحصى مٮد أواحر السٮعٮٮٮاٮ طرٮڡه اسٮحدام الٮاس للٮلڡار ڡى مٮارلهم. ڡمٮلا، أصٮحٮ أحهره الٮلڡار ٮسٮعمل ڡى ممارسه الألعاٮ الإلكٮروٮٮه، واسٮڡٮال حدماٮ المعلوماٮ الٮلڡارٮه. الٮلڡار والعٮڡ  كمٮه العٮڡ المعروصه ڡى المرٮاه (الٮلڡار) ڡى محٮلڡ أٮحاء العالم ٮرٮڡع ٮسكل مطرد، حٮٮ ٮساهد الأطڡال ڡى ٮعص الڡٮواٮ مں 5000 إلى 2000 مسهد عٮڡ كل سٮه ٮما ڡى دلك الڡٮل والاعٮصاٮ. أكٮر مں 1000 دراسه مورعه ڡى العالم على العلاڡه الحدلٮه ٮٮں العٮڡ الممارس ٮومٮا ڡى المحٮط المدرسى والمحٮمع والعٮڡ الٮى ٮٮٮه الٮرامح الٮلڡارٮه حاصه للدكور. الڡئاٮ المعرصه أكٮر مں عٮرها هى الأطڡال مں أٮٮاء الأڡلٮاٮ مں المهاحرٮں والٮارحٮں. والأطڡال الدٮں ٮسكوں مں اصطراٮاٮ اٮڡعالٮه وعاطڡٮه. والأطڡال الدٮں ٮسكوں مں صعوٮاٮ دراسٮه أو ٮكٮٮڡٮه، والأطڡال الدٮں
#
#  يوجد نوعان من محطات التلفاز: المحطات التجارية والمحطات العامة. تدار المحطات التجارية بواسطة شركات خاصة. وتبيع هذه الشركات وقت الإعلانات لتغطية نفقات التشغيل، بالإضافة لتحقيق ربح للشركات التي تدير المحطات. أما محطات التلفاز العامة فهي محطات لا تهدف إلى الربح وتدار وفق ترتيبات خاصة. فمثلا تحصل هيئة الإذاعة البريطانية على التمويل من رسوم الترخيص التي يدفعها مالكو أجهزة التلفاز وهي لا تبيع وقتا للإعلانات. وتعتمد محطات التلفاز العامة في معظم الدول، على مساهمات قطاع الأعمال، والحكومة، والجمهور، وذلك لتغطية نفقات التشغيل، ومن ثم فإنهم يتخذون قراراتهم بشأن محتويات البرامج بأنفسهم. وفي دول أخرى تقوم الحكومات بإدارة محطات التلفاز التي تتخذ القرارات بشأن محتويات البرامج. وبصفة عامة لا تبيع هذه المحطات وقتا للإعلان. يستطيع الأفراد في بعض الدول الاشتراك في أنظمة التلفاز الكبلي (خط المايكروويف) وأنظمة البث لمشاهدون رسوما لهذه الخدمات. كما توجد استخدامات أخرى للتلفاز غير بث البرامج للمنازل. فمثلا، تستخدم المدارس، وقطاع الأعمال، والمستشفيات، وغيرها من المنظمات دوائر التلفاز المغلقة. وترسل الإشارات في مثل هذه الدوائر عبر أسلاك إلى أجهزة تلفاز بعينها، ولا تستطيع بقية الأجهزة الموجودة في المنطقة التقاط تلك الإشارات بالطريقة العادية. وقد غيرت الأجهزة الحديثة كمسجلات الفيديو كاسيت، ومشغلات أقراص الفيديو، والحاسوب الشخصي منذ أواخر السبعينيات طريقة استخدام الناس للتلفاز في منازلهم. فمثلا، أصبحت أجهزة التلفاز تستعمل في ممارسة الألعاب الإلكترونية، واستقبال خدمات المعلومات التلفازية. التلفاز والعنف  كمية العنف المعروضة في المرناة (التلفاز) في مختلف أنحاء العالم ترتفع بشكل مطرد، حيث يشاهد الأطفال في بعض القنوات من 5000 إلى 2000 مشهد عنف كل سنة بما في ذلك القتل والاغتصاب. أكثر من 1000 دراسة موزعة في العالم على العلاقة الجدلية بين العنف الممارس يوميا في المحيط المدرسي والمجتمع والعنف التي تبثه البرامج التلفازية خاصة للذكور. الفئات المعرضة أكثر من غيرها هي الأطفال من أبناء الأقليات من المهاجرين والنازحين. والأطفال الذين يشكون من اضطرابات انفعالية وعاطفية. والأطفال الذين يشكون من صعوبات دراسية أو تكييفية، والأطفال الذين

# %%
def get_vocab(data):
    vocab = set()
    for sentence in data:
        for letter in sentence:
            vocab.update(letter)
            
    vocab = sorted(vocab)
    
    char2index = {'<PAD>': 0}
    index2char = {0: '<PAD>'}
    for index, char in enumerate(vocab, len(index2char)):
        char2index[char] = index
        index2char[index] = char

    return vocab, char2index, index2char

# Create a vocab
dottless_chars, dottless_char2index, dottless_index2char = get_vocab(dottless_text_list)
original_chars, original_char2index, original_index2char = get_vocab(original_text_list)

# Convert to index
dottless_text_list_encoded = []
for sentence in dottless_text_list: 
    dottless_text_list_encoded.append([dottless_char2index[char] for char in sentence])

original_text_list_encoded = []
for sentence in original_text_list:
    original_text_list_encoded.append([original_char2index[char] for char in sentence])

# %%
def pad_sequence(x, max_len, pad_token_index=0):
    padded = np.full((max_len), fill_value=pad_token_index)
    if len(x) > max_len: padded[:] = x[:max_len]
    else: padded[:len(x)] = x
    return padded

# pad the sequences
max_length = 512
dottless_text_list_padded = [pad_sequence(sequence, max_length) for sequence in dottless_text_list_encoded]
original_text_list_padded = [pad_sequence(sequence, max_length) for sequence in original_text_list_encoded]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(dottless_text_list_padded, original_text_list_padded, test_size=0.1, random_state=42)

# %%
class ArabicDottizationDataset(Dataset):
    def __init__(self, dottless_text, original_text):
        self.dottless_text = dottless_text
        self.original_text = original_text
         
    def __len__(self):
        return len(self.dottless_text)

    def __getitem__(self, index):     
        return torch.tensor(self.dottless_text[index]), torch.tensor(self.original_text[index])

# %%
train_dataset = ArabicDottizationDataset(x_train, y_train)
test_dataset = ArabicDottizationDataset(x_test, y_test)

# %% [markdown]
# # The Model

# %%
class ArabicDottizationModel(nn.Module):
    def __init__(self, dotless_vocab_size, dotted_vocab_size, embedding_dim, hidden_size):
        super().__init__()
        
        self.embedding = nn.Embedding(dotless_vocab_size, embedding_dim)
        self.rnn = nn.GRU(embedding_dim, hidden_size, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, dotted_vocab_size)
        
        
    def forward(self, dotless_sentence):
        embeddings = self.embedding(dotless_sentence)  
        embeddings = embeddings.transpose(0, 1)  
        output, _ = self.rnn(embeddings)  
        output = self.fc(output)  
        output = output.transpose(0, 1)  
        return output

# %%
embed_size = 512
hidden_size = 256
dottless_vocab_size = len(dottless_char2index)
dotted_vocab_size = len(original_char2index)
learning_rate = 1e-4
num_epochs = 20
batch_size = 128

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = ArabicDottizationModel(dottless_vocab_size, dotted_vocab_size, embed_size, hidden_size).to(device)

criterion = nn.CrossEntropyLoss(ignore_index=original_char2index['<PAD>'])
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
model.train()

for epoch in range(num_epochs):
    running_loss = 0.0
    for i, (inputs, labels) in tqdm(
        enumerate(train_loader), total=len(train_loader), leave=False
    ):
        inputs, labels = inputs.to(device), labels.to(device).long()

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
         
        outputs = outputs.reshape(-1, dotted_vocab_size) 
        labels = labels.reshape(-1)
         
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print('Loss: {}'.format(running_loss))

print('Finished Training')
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 180.86547231674194
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 46.453004002571106
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 31.329570204019547
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 26.795734763145447
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 24.662041276693344
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 23.299795389175415
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 22.262065321207047
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 21.382335543632507
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 20.58946317434311
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 19.86083386838436
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 19.173649564385414
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 18.51979334652424
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 17.906156450510025
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 17.337458208203316
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 16.802503034472466
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 16.301955446600914
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 15.83448974788189
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 15.40352013707161
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 14.985851496458054
#   0%|          | 0/79 [00:00<?, ?it/s]
# Loss: 14.604834854602814
# Finished Training

# %%
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
 
model.eval()

for image, gt in test_loader:
    image = image.to(device)
    outputs = model(image) 
    predicted = outputs.argmax(2).cpu() 
    print('Dottless Text:')
    print(''.join([dottless_index2char[c.item()] for c in image[0]]))

    print('\nModel Text:') 
    print(''.join([original_index2char[c.item()] for c in predicted[0]]))
 
    print('\nActual Text:')
    print(''.join([original_index2char[c.item()] for c in gt[0]])) 
    print('-' * 40)
# Out:
# Dottless Text:
# أٮار ڡرٮه مں مارعرٮٮ العٮره ڡى والدٮه، الٮى حاولٮ أں ٮڡصل ٮٮں الروحٮں ڡدر اسٮطاعٮها. حمله الڡدٮس لوٮس الصلٮٮٮه  ڡى عام 1229، عٮدما كاں لوٮس ٮٮلع مں العمر 15 عاما، أٮهٮ والدٮه الحمله الصلٮٮٮه الألٮٮحٮٮٮه ٮٮوڡٮع اٮڡاڡٮه مع رٮموٮد الساٮع ملك ٮولور. كاں رٮموں السادس ملك ٮولور ٮسٮٮه ڡى أٮه أمر ٮاعٮٮال ٮٮٮر دى كاسٮٮلٮاو، وهو واعط كاٮولٮكى روماٮى حاول ٮحوٮل الكاٮارٮٮں. ڡاد لوٮس حملٮٮں صلٮٮٮٮٮں: الحمله الصلٮٮٮه الساٮعه عام 1248 والحمله الصلٮٮٮه الٮامٮه عام 1270. الحمله الصلٮٮٮه الساٮعه  وصل لوٮس وأٮٮاعه إلى مصر ڡى
#
# Model Text:
# أبار قرية من مارغريت الغيرة في والدية، التي حاولت أن يفصل بين الروحين قدر استطاعتها. حملة القديس لويس الصليبية  في عام 1229، عندما كان لويس ببلغ من العمر 15 عاما، أنهب والدية الحملة الصليبية الألييجييية تتوفيع اتقافية مع ريمويد السابع ملك بولور. كان ريمون السادس ملك بولوز بسبية في أنه أمر باعتبال ببير ذي كاستيلياو، وهو واعط كاتوليكي روماني حاول تحويل الكاباريين. فاد لويس حمليين صلييييين: الحملة الصليبية السابعة عام 1248 والحملة الصليبية التامية عام 1270. الحملة الصليبية السابعة  وصل لويس وأنناعة إلى مصر في
#
# Actual Text:
# أثار قربه من مارغريت الغيرة في والدته، التي حاولت أن تفصل بين الزوجين قدر استطاعتها. حملة القديس لويس الصليبية  في عام 1229، عندما كان لويس يبلغ من العمر 15 عاما، أنهت والدته الحملة الصليبية الألبيجينية بتوقيع اتفاقية مع ريموند السابع ملك تولوز. كان ريمون السادس ملك تولوز يشتبه في أنه أمر باغتيال بيير دي كاستيلناو، وهو واعظ كاثوليكي روماني حاول تحويل الكاثاريين. قاد لويس حملتين صليبيتين: الحملة الصليبية السابعة عام 1248 والحملة الصليبية الثامنة عام 1270. الحملة الصليبية السابعة  وصل لويس وأتباعه إلى مصر في
# ----------------------------------------
# Dottless Text:
# صار أسٮادا مساعدا ڡى ٮڡس الڡسم والكلٮه ڡى ٮولٮو سٮه 1949. ٮرك حامعه الڡاهره (ڡؤاد) ڡى 19 سٮٮمٮر 1950، لٮڡوم ٮإٮساء ڡسم الڡلسڡه ڡى كلٮه الآداٮ ڡى حامعه عٮں سمس، حامعه إٮراهٮم ٮاسا ساٮڡا، وڡى ٮٮاٮر 1959 أصٮح أسٮاد كرسى. عمل مسٮسارا ٮڡاڡٮا ومدٮر الٮعٮه الٮعلٮمٮه ڡى ٮٮرں ڡى سوٮسرا مارس 1956 - ٮوڡمٮر 1958 عادر إلى ڡرٮسا 1967 ٮعد أں حردٮ ٮوره 23 ٮولٮو عائلٮه مں أملاكها. وكاں ڡد عمل كأسٮاد رائر ڡى العدٮد مں الحامعاٮ، (1947-1949) ڡى الحامعاٮ اللٮٮاٮٮه، (ڡٮراٮر 1967 - ماٮو 1967) ڡى معهد الدراساٮ الإسلامٮه ڡى كلٮه ال
#
# Model Text:
# صار أسبادا مساعدا في نفس القسم والكلية في بوليو سنة 1949. ترك جامعة القاهرة (فؤاد) في 19 ستتمير 1950، ليقوم بإنشاء قسم الفلسفة في كلية الآدات في جامعة عين سمس، جامعة إبراهيم باسا سابقا، وفي يناير 1959 أصبح أسباد كرسي. عمل مستشارا بقافيا ومدير البعية التعليمية في بيرن في سويشرا مارس 1956 - توفمبر 1958 عادر إلى فرنسا 1967 بعد أن جردت بورة 23 بوليو عائلية من أملاكها. وكان قد عمل كأسياد زائر في العديد من الجامعات، (1947-1949) في الجامعات اللبنانية، (فبراير 1967 - مايو 1967) في معهد الدراسات الإسلامية في كلية ال
#
# Actual Text:
# صار أستاذا مساعدا في نفس القسم والكلية في يوليو سنة 1949. ترك جامعة القاهرة (فؤاد) في 19 سبتمبر 1950، ليقوم بإنشاء قسم الفلسفة في كلية الآداب في جامعة عين شمس، جامعة إبراهيم باشا سابقا، وفي يناير 1959 أصبح أستاذ كرسى. عمل مستشارا ثقافيا ومدير البعثة التعليمية في بيرن في سويسرا مارس 1956 - نوفمبر 1958 غادر إلى فرنسا 1967 بعد أن جردت ثورة 23 يوليو عائلته من أملاكها. وكان قد عمل كأستاذ زائر في العديد من الجامعات، (1947-1949) في الجامعات اللبنانية، (فبراير 1967 - مايو 1967) في معهد الدراسات الإسلامية في كلية ال
# ----------------------------------------
# Dottless Text:
# كوكٮ أوراٮوس (ودلك ٮٮاء على اصطراٮ ڡى مدار أوراٮوس). ولڡد أكمل آدامر دراساٮه ومں ٮم أرسلها إلى السٮر حورح ٮٮدل أٮرى  العالم الڡلكى الملكى ڡى إٮحلٮرا  والدى روده ڡى ڡٮراٮر 1844. وڡد اسٮمر آدامر ٮعمله عام 45-1846 وحصل على العدٮد مں الٮڡدٮراٮ المحٮلڡه للكوكٮ الحدٮد. وڡى الوڡٮ ٮڡسه ٮدأ أورٮاں لوڡٮرٮى - وهو ساٮ لم ٮكں ٮعرڡه آدامر - ڡى العمل على المسروع، اڡٮرح ٮأں هٮاك كوكٮا ٮامٮا ڡى المٮطومه السمسٮه، لاڡٮا إلى اں هٮاك حللا ڡى مدار الكوكٮ أوراٮوس. وأٮٮٮ لوڡٮرٮى، ڡٮل عام على رسالٮه، أں كل الٮطرٮاٮ المٮداوله لا ٮڡس
#
# Model Text:
# كوكت أورانوس (وذلك بناء على اضطرات في مدار أوراتوس). ولقد أكمل آدامر دراساتة ومن ثم أرسلها إلى الشير جورج ببدل أبري  العالم الفلكي الملكي في إنجليزا  والذي رودة في فبراير 1844. وقد استمر آدامر بعملة عام 45-1846 وحصل على العديد من التقديرات المختلفة للكوكت الجديد. وفي الوقت نفسه بدأ أوريان لوفيرتي - وهو ساب لم يكن تعرفة آدامر - في العمل على المشروع، اقترج بأن هناك كوكيا ياميا في المنطومة السمسية، لاقتا إلى ان هناك خللا في مدار الكوكت أورانوس. وأبيت لوفيرتي، قبل عام على رسالية، أن كل النطريات المتداولة لا تقس
#
# Actual Text:
# كوكب أورانوس (وذلك بناء على اضطراب في مدار أورانوس). ولقد أكمل آدامز دراساته ومن ثم أرسلها إلى السير جورج بيدل أيري  العالم الفلكي الملكي في إنجلترا  والذي زوده في فبراير 1844. وقد استمر آدامز بعمله عام 45-1846 وحصل على العديد من التقديرات المختلفة للكوكب الجديد. وفي الوقت نفسه بدأ أوربان لوفيريي - وهو شاب لم يكن يعرفه آدامز - في العمل على المشروع، اقترح بأن هناك كوكبا ثامنا في المنظومة الشمسية، لافتا إلى ان هناك خللا في مدار الكوكب أورانوس. وأثبت لوفيريي، قبل عام على رسالته، أن كل النظريات المتداولة لا تفس
# ----------------------------------------
# Dottless Text:
# وهو السٮه ال93 ڡى الڡرں العسرٮں والراٮعه ڡى عڡد 1990. أحداٮ   دٮسمٮر: ٮهاٮه حصار موسٮار والدى ٮدأ ڡى 3 أٮرٮل 1992.  ٮهاٮه الصراع الحورحى الأٮحارى ڡى 1993 والٮى ٮدأ ڡى 1989. ٮٮاٮر   1 ٮٮاٮر -  اٮڡصال ٮسٮكسلوڡاكٮا إلى دولٮٮں حمهورٮه الٮسٮك وسلوڡاكٮا ڡى اٮڡصال هادئ.  الاٮحاد الاورٮى ٮرٮل الڡٮود الٮحارٮه ٮٮں دوله معلٮا ٮدء السوٯ الأورٮٮه الموحده.  2 ٮٮاٮر - الرئٮس حورح ٮوس وٮورٮس ٮلٮسٮں رئٮس روسٮا ٮوڡعا المعاهده الٮاٮٮه لحڡص الأسلحه الإسٮراٮٮحٮه ڡى موسكو.  3 ٮٮاٮر -  الولاٮاٮ المٮحده ٮٮڡد أول حاله إعدام سٮڡا مٮ
#
# Model Text:
# وهو السية ال93 في القرن العشرين والرابعة في عقد 1990. أحداث   ديسمير: نهاية حصار موسيار والذي بدأ في 3 أبريل 1992.  نهاية الصراع الجورجي الأنجاري في 1993 والتي بدأ في 1989. يناير   1 يناير -  انفصال تشتكسلوفاكيا إلى دوليين جمهورية التشيك وسلوفاكيا في انفصال هادئ.  الاتحاد الاورتي بزيل الفيود التجارية بين دولة معليا بدء السوق الأوربية الموحدة.  2 يناير - الرئيس جورج بوس وتوريس بلنسين رئيس روسيا توفعا المعاهدة الثانية لخقض الأسلحة الإسبراتيخية في موسكو.  3 يناير -  الولايات المتحدة تنقد أول حالة إعدام سيقا مت
#
# Actual Text:
# وهو السنة ال93 في القرن العشرين والرابعة في عقد 1990. أحداث   ديسمبر: نهاية حصار موستار والذي بدأ في 3 أبريل 1992.  نهاية الصراع الجورجي الأبخازي في 1993 والتي بدأ في 1989. يناير   1 يناير -  انفصال تشيكسلوفاكيا إلى دولتين جمهورية التشيك وسلوفاكيا في انفصال هادئ.  الاتحاد الاوربي يزيل القيود التجارية بين دوله معلنا بدء السوق الأوربية الموحدة.  2 يناير - الرئيس جورج بوش وبوريس يلتسين رئيس روسيا يوقعا المعاهدة الثانية لخفض الأسلحة الإستراتيجية في موسكو.  3 يناير -  الولايات المتحدة تنفذ أول حالة إعدام شنقا من
# ----------------------------------------
# Dottless Text:
# الدكٮوراه ڡى الدراساٮ العرٮٮه الإسلامٮه، ٮحصص الڡلسڡه والٮصوڡ. إٮه أحد الٮاحٮٮں الدى ٮڡرأ ٮعده ٮڡدٮه الڡكر الكلاسٮكى والڡكر المعاصر. ڡراءٮه لـ حاك درٮدا وهاٮس حٮورع عادامٮر أٮاحٮ له ڡراءه الٮصوص الڡلسڡٮه والعرڡاٮٮه ٮأدواٮ ٮڡدٮه معاصره. كما أٮه معحٮ ٮالڡٮلسوڡ اللٮٮاٮى على حرٮ حٮٮ كٮٮ عٮه ودكره ڡى عده كٮٮه. وٮرحم أحد كٮٮه إلى الڡرٮسٮه. اٮه ٮسٮعل الآں على اٮں عرٮى حٮٮ كاں موصوع رساله الدكٮوراه. ٮسٮلهم العدٮد مں أڡكاره مں هدا المڡكر الصوڡى الأٮدلسى. وٮحصل سٮه 2011 على دكٮوراه ٮاٮٮه ڡى الڡلسڡه حول المؤرح والمڡكر
#
# Model Text:
# الدكتوراة في الدراسات العربية الإسلامية، تخصص الفلسفة والتصوف. إنه أحد التاحيين الذي يقرأ بعدة تقدية الفكر الكلاسيكي والفكر المعاصر. قراءية لـ حاك دريدا وهانس جيورع عادامير أناحت له قراءة التصوص الفلسفية والعرقانية بأدوات تقدية معاصرة. كما أنه معجب بالفيلسوف اللبباتي على حرب حيث كيب عنه وذكرة في عدة كبية. وترجم أحد كبية إلى الفرنسية. انه تستعل الآن على ابن غربي حيث كان موضوع رسالة الذكتوراة. تسيلهم العديد من أفكارة من هذا المفكر الصوفي الأندلسي. وتحصل سنة 2011 على ذكتوراه بانية في الفلسفة حول المؤرح والمفكر
#
# Actual Text:
# الدكتوراه في الدراسات العربية الإسلامية، تخصص الفلسفة والتصوف. إنه أحد الباحثين الذي يقرأ بعدة نقدية الفكر الكلاسيكي والفكر المعاصر. قراءته لـ جاك دريدا وهانس جيورغ غادامير أتاحت له قراءة النصوص الفلسفية والعرفانية بأدوات نقدية معاصرة. كما أنه معجب بالفيلسوف اللبناني علي حرب حيث كتب عنه وذكره في عدة كتبه. وترجم أحد كتبه إلى الفرنسية. انه يشتغل الآن على ابن عربي حيث كان موضوع رسالة الدكتوراه. يستلهم العديد من أفكاره من هذا المفكر الصوفي الأندلسي. وتحصل سنة 2011 على دكتوراه ثانية في الفلسفة حول المؤرخ والمفكر
# ----------------------------------------
# Dottless Text:
# الأحرى، لٮسمل الصوٮ الدى ٮمٮله. ٮدأ الٮطٯ الكاٮولٮكى (هٮٮس) ڡى الاحٮڡاء داحل المملكه المٮحده ڡلم ٮعد ٮسٮعمله سوى 24% مں المردادٮں ٮعد سٮه 1982. ٮحٮلڡ الآراء حول ٮارٮح اسم الحرڡ ڡڡاموس أوكسڡورد الإٮحلٮرى ٮڡول أں الاسم الأصلى للحرڡ كاں  وأصٮح  ڡى اللاٮٮٮٮه ودحل الإٮحلٮرٮه مں الڡرٮسٮه العٮٮڡه  وكاں ٮٮطٯ ڡى الإٮحلٮرٮه الوسٮطٮه . أما ڡاموس الٮراٮ الأمرٮكى للعه الإٮحلٮرٮه ڡٮڡول أں الاسم حاء مں الڡرٮسٮه آس  الدى ٮدوره حاء مں اللاٮٮٮٮه هاكا  أو هٮك . اللعه الألماٮٮه  ڡى اللعه الألماٮٮه، ٮسمى  ها  وٮٮڡى وطٮڡٮه الأسا
#
# Model Text:
# الأخرى، لتشمل الصوت الذي يمثلة. بدأ النطق الكاتوليكي (هنيس) في الاحتفاء داخل المملكة المتحدة فلم بعد تستعملة سوى 24% من المردادين بعد سنة 1982. تختلف الآراء حول تاريخ اسم الحرف فقاموس أوكسفورد الإنجليزي يقول أن الاسم الأصلى للحرف كان  وأصبح  في اللاثينية ودخل الإنجليزية من الفرنسية العبيقة  وكان بنطق في الإنجليزية الوسيطية . أما قاموس الترات الأمريكي للعة الإنجليزية فيقول أن الاسم جاء من الفرنسية آس  الذي يدورة جاء من اللاثينية هاكا  أو هنك . اللغة الألمانية  في اللغة الألمانية، تسمى  ها  وتنفى وطيقية الأسا
#
# Actual Text:
# الأخرى، لتشمل الصوت الذي تمثله. بدأ النطق الكاثوليكي (هيتش) في الاختفاء داخل المملكة المتحدة فلم يعد يستعمله سوى 24% من المزدادين بعد سنة 1982. تختلف الآراء حول تاريخ اسم الحرف فقاموس أوكسفورد الإنجليزي يقول أن الاسم الأصلي للحرف كان  وأصبح  في اللاتينية ودخل الإنجليزية من الفرنسية العتيقة  وكان ينطق في الإنجليزية الوسيطية . أما قاموس التراث الأمريكي للغة الإنجليزية فيقول أن الاسم جاء من الفرنسية آش  الذي بدوره جاء من اللاتينية هاكا  أو هيك . اللغة الألمانية  في اللغة الألمانية، يسمى  ها  وتبقى وظيفته الأسا
# ----------------------------------------
# Dottless Text:
# ٮصڡه الٮأحٮر ڡى الٮصح أى أں للٮأٮٮر الوراٮى دور لا ٮڡل أهمٮه عں الٮأٮٮر الٮٮئى ڡى ٮأحٮر الٮصح للٮمار. ولا ٮڡوٮٮا ڡى هدا المحال أں ٮدكر ڡٮام معهد ٮحوٮ الٮساٮٮں ٮاسٮٮراد سلالاٮ مں الحواڡه الٮٮصاء والحمراء مں المكسٮك ومالٮرٮا ٮحٮ اسم المسروع المحاصٮل عٮر الٮڡلٮدٮه وڡد ٮم رراعٮها ٮحدٮڡه ٮحارٮ الڡاكهه ٮالمعهد لٮڡٮٮمها واٮٮحاٮ أڡصل السلالاٮ مٮها والعمل على إكٮارها حصرٮا وٮورٮعها على الڡلاحٮں والمٮٮحٮں الأهمٮه العدائٮه للحواڡه  ٮؤكل ٮمار الحواڡه طارحه أوكسرائح محڡوطه ڡى محالٮل سكرٮه أو مطٮوحه (مرٮى) كعصٮر. وٮمار ا
#
# Model Text:
# نصفة التأخير في التصح أي أن للتأثير الوراتي دور لا تقل أهمية عن التأثير البيئي في تأخير التصح للتمار. ولا يقونيا في هذا المجال أن يذكر قيام معهد تحوت التسابين باستتراد سلالات من الحوافة البيضاء والحمراء من المكسيك وماليريا بحت اسم المشروع المحاصيل غير التقليدية وقد ثم زراعيها تحديفة تحارب الفاكهة بالمعهد لتقييمها وانتحاب أفصل السلالات منها والعمل على إكبارها حصريا وتوريعها على الفلاحين والمنتجين الأهمية العدائية للحوافة  تؤكل بمار الحوافة طارجة أوكسرائح محقوظة في محاليل سكرية أو مطيوجة (مرتي) كعصير. وتمار ا
#
# Actual Text:
# بصفة التأخير في النضج أي أن للتأثير الوراثي دور لا يقل أهمية عن التأثير البيئي في تأخير النضج للثمار. ولا يفوتنا في هذا المجال أن نذكر قيام معهد بحوث البساتين باستيراد سلالات من الجوافة البيضاء والحمراء من المكسيك وماليزيا تحت اسم المشروع المحاصيل غير التقليدية وقد تم زراعتها بحديقة تجارب الفاكهة بالمعهد لتقييمها وانتخاب أفضل السلالات منها والعمل على إكثارها خضريا وتوزيعها على الفلاحين والمنتجين الأهمية الغذائية للجوافة  تؤكل ثمار الجوافة طازجة أوكشرائح محفوظة في محاليل سكرية أو مطبوخة (مربى) كعصير. وثمار ا
# ----------------------------------------
# Dottless Text:
# الهٮاكل العطمٮه والأدواٮ الححرٮه والعطمٮه وكدلك الحلى وٮڡاٮا عطام الحٮواٮاٮ. وسمى الإٮساں المكٮسڡ ٮاسم إٮساں ٮاڡوعالٮ. وڡد اكٮسڡ مؤحرا ڡرٮٯ مں الٮاحٮٮں محموعه حدٮده مں الحلى ٮعٮٮر الأڡدم ڡى العالم. أڡدم الحلى - ما ٮٮں 84 ألڡ سٮه و85 ألڡ سٮه  اكٮسڡ ڡرٮٯ مں الٮاحٮٮں محموعه حدٮده مں الحلى ٮعٮٮر الأڡدم ڡى العالم. وڡال ٮٮاں لوراره الٮڡاڡه المعرٮٮه إں ڡرٮڡا علمٮا اكٮسڡ حوالى 20 مں الصدڡٮاٮ الٮحرٮه الٮى اسٮعملها الإٮساں الڡدٮم كحلى، ڡى إطار الأٮحاٮ الأٮرٮه الٮى ٮڡوم ٮها المعهد الوطٮى لعلوم الآٮار والٮراٮ، ٮالٮعاوں
#
# Model Text:
# الهباكل العظمية والأدوات الحجرية والعظمية وكذلك الخلي ويقانا عظام الحنوانات. وسمى الإنسان المكتشف باسم إنسان بافوغالت. وقد اكتشف مؤجرا فريق من التاحيين مجموعة جديدة من الخلي تعتير الأقدم في العالم. أقدم الخلي - ما بين 84 ألف سية و85 ألف سية  اكتشف فريق من التاحيين مجموعة جديدة من الخلي تعتير الأقدم في العالم. وقال بنان لوزارة الثقافة المعربية إن فريقا علميا اكتشف حوالي 20 من الصدفيات البحرية التي استعملها الإنسان القديم كخلي، في إطار الأنحاب الأثرية التي تقوم بها المعهد الوطني لعلوم الآثار والترات، بالتعاون
#
# Actual Text:
# الهياكل العظمية والأدوات الحجرية والعظمية وكذلك الحلي وبقايا عظام الحيوانات. وسمي الإنسان المكتشف باسم إنسان تافوغالت. وقد اكتشف مؤخرا فريق من الباحثين مجموعة جديدة من الحلي تعتبر الأقدم في العالم. أقدم الحلي - ما بين 84 ألف سنة و85 ألف سنة  اكتشف فريق من الباحثين مجموعة جديدة من الحلي تعتبر الأقدم في العالم. وقال بيان لوزارة الثقافة المغربية إن فريقا علميا اكتشف حوالي 20 من الصدفيات البحرية التي استعملها الإنسان القديم كحلي، في إطار الأبحاث الأثرية التي يقوم بها المعهد الوطني لعلوم الآثار والتراث، بالتعاون
# ----------------------------------------
# Dottless Text:
# رلرال ڡى مٮٮصڡ الڡرں الٮامں عسر، ٮم ٮهٮها الحكام المعرٮٮوں وأحدوا أححارها لٮٮاء مدٮٮه مكٮاس. ولم ٮٮم الٮعرڡ على الموڡع ٮأٮه مدٮٮه ولٮلى الڡدٮمه حٮى الحرء الأحٮر مں الڡرں الٮاسع عسر. حلال وٮعد ڡٮره الحكم الڡرٮسى على المعرٮ، ٮم حڡر حوالى ٮصڡ الموڡع، وٮم الكسڡ عں العدٮد مں الڡسٮڡساء الحمٮله، وٮعص المٮاٮى العامه الأكٮر ٮرورا والمٮارل عالٮه المسٮوى الٮى ٮم ٮرمٮمها أو إعاده ٮٮائها. والٮوم ٮعد المدٮٮه مں ٮٮں مواڡع الٮراٮ العالمى للٮوٮسكو، لكوٮها مٮالا اسٮٮٮائٮا محاڡط علٮه حٮدا على ٮلده اسٮعمارٮه روماٮٮه كٮٮره على
#
# Model Text:
# زلزال في منتصف القرن الثامن عشر، ثم يهنها الحكام المعرييون وأحدوا أحجارها لبناء مدينة مكناس. ولم يتم التعرف على الموقع بأنه مدينة وليلي القديمة حتى الجزء الأخير من القرن التاسع عشر. خلال وبعد فيرة الحكم الفرنسي على المغرب، ثم حفر حوالي نصف الموقع، وتم الكسف عن العديد من الفسنقساء الجميلة، وبعض المثاني العامة الأكثر برورا والمنازل غالية المستوى التي تم ترميمها أو إعادة بنائها. واليوم بعد المدينة من بين مواقع الترات العالمي للتويسكو، لكونها مثالا استبنائيا محافظ عليه جيدا على بلدة استعمارية رومانية كبيرة على
#
# Actual Text:
# زلزال في منتصف القرن الثامن عشر، ثم نهبها الحكام المغربيون وأخدوا أحجارها لبناء مدينة مكناس. ولم يتم التعرف على الموقع بأنه مدينة وليلي القديمة حتى الجزء الأخير من القرن التاسع عشر. خلال وبعد فترة الحكم الفرنسي على المغرب، تم حفر حوالي نصف الموقع، وتم الكشف عن العديد من الفسيفساء الجميلة، وبعض المباني العامة الأكثر بروزا والمنازل عالية المستوى التي تم ترميمها أو إعادة بنائها. واليوم تعد المدينة من بين مواقع التراث العالمي لليونسكو، لكونها مثالا استثنائيا محافظ عليه جيدا على بلدة استعمارية رومانية كبيرة على
# ----------------------------------------
